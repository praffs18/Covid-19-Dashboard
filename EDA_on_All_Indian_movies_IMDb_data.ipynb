# %% [markdown]
# <a href="https://colab.research.google.com/github/praffs18/Covid-19-Dashboard/blob/main/EDA_on_All_Indian_movies_IMDb_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# EDA on All Indian movies IMDb Data
#
# This dataset of 15506 Indian movies taken from IMDb. This is all the Indian movies on IMDb as of 16/06/2021.

# %%
# import all libraries
import pandas as pd 
import numpy as np

# import visualisation libraries
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# Mount the google drive
from google.colab import drive
drive.mount('/content/drive',force_remount = True)
# Out:
# Mounted at /content/drive

# %%
# Load the data
path  = "/content/drive/MyDrive/Data Science/EDA Projects/EDA on All Indian movies IMDb Data/IMDb Movies India.csv"
data = pd.read_csv(path,encoding='latin-1')
data.head()
# Out:
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                         #Homecoming  (2021)   90 min   Drama, Musical
# 3                             #Yaaram  (2019)  110 min  Comedy, Romance
# 4                   ...And Once Again  (2010)  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# 3  Siddhant Kapoor
# ...

# %%
data.tail()
# Out:
#                       Name    Year Duration          Genre  Rating Votes  \
# 15504  Zulm Ko Jala Doonga  (1988)      NaN         Action     4.6    11
# 15505                Zulmi  (1999)  129 min  Action, Drama     4.5   655
# 15506            Zulmi Raj  (2005)      NaN         Action     NaN   NaN
# 15507        Zulmi Shikari  (1988)      NaN         Action     NaN   NaN
# 15508         Zulm-O-Sitam  (1998)  130 min  Action, Drama     6.2    20
#
#             Director           Actor 1         Actor 2        Actor 3
# 15504  Mahendra Shah  Naseeruddin Shah   Sumeet Saigal  Suparna Anand
# 15505     Kuku Kohli      Akshay Kumar  Twinkle Khanna    Aruna Irani
# 15506     Kiran Thej   Sangeeta Tiwari             NaN            NaN
# 15507            NaN               NaN             NaN            NaN
# 15508   K.C. Bokadia        Dharmendra      Jaya Prada    Arjun Sarja

# %%
# Check how many rows and columns in data
print(f'No. of rows are : {data.shape[0]}')
print(f'No. of feature columns are : {data.shape[1]}')
# Out:
# No. of rows are : 15509
# No. of feature columns are : 10

# %%
# check all information about the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      14981 non-null  object
#  2   Duration  7240 non-null   object
#  3   Genre     13632 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     7920 non-null   object
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 1.2+ MB

# %%
# Make copy of the data and start doing changes
data_1 = data.copy()
data_1.head()
# Out:
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                         #Homecoming  (2021)   90 min   Drama, Musical
# 3                             #Yaaram  (2019)  110 min  Comedy, Romance
# 4                   ...And Once Again  (2010)  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# 3  Siddhant Kapoor
# ...

# %%
# Remove # sign in the name column
data_1['Name'] = data_1["Name"].str.replace('#','')
data_1.head()
# Out:
#                                 Name    Year Duration            Genre  \
# 0                                        NaN      NaN            Drama
# 1  Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                         Homecoming  (2021)   90 min   Drama, Musical
# 3                             Yaaram  (2019)  110 min  Comedy, Romance
# 4                  ...And Once Again  (2010)  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# 3  Siddhant Kapoor
# ...

# %%
# Remove parenthesis in year column and remove text 'min' from Duration column and also replace some string in Votes columns
data_1['Year'] = data_1['Year'].str.replace('(','').str.replace(')','')
data_1['Duration'] = data_1['Duration'].str.replace('min','')
data_1["Votes"]=data_1["Votes"].replace("$5.16M", 516).str.replace(',','')
data_1.rename(columns = {'Duration':'Duration (min)'},inplace = True)
data_1.head()
# Out:
#                                 Name  Year Duration (min)            Genre  \
# 0                                      NaN            NaN            Drama
# 1  Gadhvi (He thought he was Gandhi)  2019           109             Drama
# 2                         Homecoming  2021            90    Drama, Musical
# 3                             Yaaram  2019           110   Comedy, Romance
# 4                  ...And Once Again  2010           105             Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# ...

# %%
# Lets check are there any duplicates
data_1.duplicated(keep = False).value_counts()
# Out:
# False    15497
# True        12
# dtype: int64

# %% [markdown]
# This shows that there are few duplicates present in the data

# %%
# Check  what are those values are 
duplicate_data = data_1[data_1.duplicated(keep = False)]
duplicate_data
# Out:
#                             Name  Year Duration (min)     Genre  Rating Votes  \
# 1249   Arab Ka Sona - Abu Kaalia  1979            NaN    Action     NaN   NaN
# 1250   Arab Ka Sona - Abu Kaalia  1979            NaN    Action     NaN   NaN
# 1768                     Balidan  1992            NaN     Drama     NaN   NaN
# 1769                     Balidan  1992            NaN     Drama     NaN   NaN
# 4722     First Time - Pehli Baar  2009            NaN       NaN     NaN   NaN
# 4723     First Time - Pehli Baar  2009            NaN       NaN     NaN   NaN
# 9712                     Musafir   NaN            NaN  Thriller     NaN   NaN
# 9713                     Musafir   NaN            NaN  Thriller     NaN   NaN
# 13068                    Shivani  2019            NaN     Crime     NaN   NaN
# 13069                    Shivani  2019            NaN     Crime     NaN   NaN
# 13307          Slumdog Karodpati  2019           118   Thriller     NaN   NaN
# ...

# %%
# Remove Duplicate rows
data_2 = data_1.drop_duplicates(keep= 'first')
data_2.shape
# Out:
# (15503, 10)

# %%
# Lets check any duplicate in movie name column
data_2.duplicated(subset = 'Name').value_counts()
# Out:
# False    13837
# True      1666
# dtype: int64

# %% [markdown]
# From this we can say that there are duplicate movie names which need to drop

# %%
# Remove duplicate rows 
data_2 = data_1.drop_duplicates(subset = 'Name',keep='first')
data_2.shape
# Out:
# (13837, 10)

# %%
# Reset the index
data_2.set_index(np.arange(len(data_2)),inplace=True)
data_2
# Out:
#                                     Name  Year Duration (min)  \
# 0                                          NaN            NaN
# 1      Gadhvi (He thought he was Gandhi)  2019           109
# 2                             Homecoming  2021            90
# 3                                 Yaaram  2019           110
# 4                      ...And Once Again  2010           105
# ...                                  ...   ...            ...
# 13832                Zulm Ko Jala Doonga  1988            NaN
# 13833                              Zulmi  1999           129
# 13834                          Zulmi Raj  2005            NaN
# 13835                      Zulmi Shikari  1988            NaN
# 13836                       Zulm-O-Sitam  1998           130
#
#                  Genre  Rating Votes            Director           Actor 1  \
# 0                Drama     NaN   NaN       J.S. Randhawa          Manmauji
# ...

# %%
# It seems like there are null values in data and those are NaN values lets check that
missing_data = pd.DataFrame(data_2.isna().sum(),columns = ['Nan_values'])
missing_data['Missing %'] = round(missing_data['Nan_values']*100/len(data_2),2)
missing_data
# Out:
#                 Nan_values  Missing %
# Name                     0       0.00
# Year                   498       3.60
# Duration (min)        7239      52.32
# Genre                 1590      11.49
# Rating                6684      48.31
# Votes                 6684      48.31
# Director               465       3.36
# Actor 1               1439      10.40
# Actor 2               2131      15.40
# Actor 3               2804      20.26

# %% [markdown]
# From this we can see that there are lot of NaN Values are present in the data
# 1. Duration, Rating & Votes columns has Nan Values Approximately 52%, 48% & 48% respectively. which are huge in numbers.
# 2. We can drop year and Genre because we can not replace those values others we can, also they have less NaN values.

# %%
# Drop NaN Values from Year and Genre columns
data_2.dropna(subset=['Year'],inplace=True)
data_2.dropna(subset=['Genre'],inplace=True)

# %%
# Conform 
data_2.isna().sum()
# Out:
# Name                 0
# Year                 0
# Duration (min)    5455
# Genre                0
# Rating            4715
# Votes             4715
# Director           426
# Actor 1           1001
# Actor 2           1396
# Actor 3           1858
# dtype: int64

# %%
# Before filling the missing values we need to change the datatypes
data_2['Duration (min)'] = data_2['Duration (min)'].apply(pd.to_numeric)
data_2['Votes'] = data_2['Votes'].apply(pd.to_numeric)

# %%
data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11782 entries, 1 to 13836
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            11782 non-null  object
#  1   Year            11782 non-null  object
#  2   Duration (min)  6327 non-null   float64
#  3   Genre           11782 non-null  object
#  4   Rating          7067 non-null   float64
#  5   Votes           7067 non-null   float64
#  6   Director        11356 non-null  object
#  7   Actor 1         10781 non-null  object
#  8   Actor 2         10386 non-null  object
#  9   Actor 3         9924 non-null   object
# dtypes: float64(3), object(7)
# memory usage: 1012.5+ KB

# %%
data_2.describe().round(2)
# Out:
#        Duration (min)   Rating      Votes
# count         6327.00  7067.00    7067.00
# mean           127.37     5.85    2033.22
# std             29.19     1.39   12159.68
# min              2.00     1.10       5.00
# 25%            110.00     4.90      17.00
# 50%            130.00     6.00      60.00
# 75%            146.00     6.90     454.50
# max            321.00    10.00  591417.00

# %% [markdown]
# From above description we can replace missing values in
# 1. Duration column with mean
# 2. Rating column with median &
# 3. Votes column with median

# %%
# Replace the missing values 
data_2['Duration (min)'] = data_2['Duration (min)'].fillna(data_2['Duration (min)'].mean())
data_2['Rating'] = data_2['Rating'].fillna(data_2['Rating'].median())
data_2['Votes'] = data_2['Votes'].fillna(data_2['Votes'].median())

# %%
# Check whether the values replaced or not
data_2.isna().sum()
# Out:
# Name                 0
# Year                 0
# Duration (min)       0
# Genre                0
# Rating               0
# Votes                0
# Director           426
# Actor 1           1001
# Actor 2           1396
# Actor 3           1858
# dtype: int64

# %% [markdown]
# **We can not replace the null values for Director & actors column**

# %%
# Now change the float datatype to int wherever it is necessory
# So in this Duration and Votes column should be an integer
data_2['Duration (min)'] = data_2['Duration (min)'].astype(int)
data_2['Votes'] = data_2['Votes'].astype(int)
data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11782 entries, 1 to 13836
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            11782 non-null  object
#  1   Year            11782 non-null  object
#  2   Duration (min)  11782 non-null  int64
#  3   Genre           11782 non-null  object
#  4   Rating          11782 non-null  float64
#  5   Votes           11782 non-null  int64
#  6   Director        11356 non-null  object
#  7   Actor 1         10781 non-null  object
#  8   Actor 2         10386 non-null  object
#  9   Actor 3         9924 non-null   object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 1012.5+ KB

# %%
# Now we can do the Univariate analysis & Bivariate analysis
# Check the Distibution of data 
columns = ['Year','Duration (min)','Rating','Votes',]
for col in columns:
  sns.histplot(data_2[col],color = 'green',bins = 25, kde = False)
  plt.title("Distribution plot of " + col, fontsize = 15)
  plt.xlabel(col,fontsize = 13)
  plt.ylabel("Density",fontsize = 13)
  plt.show()

# %%
# Top 10 best rated movie
best_rated_movie = data_2[['Name','Year','Rating']].sort_values(by = 'Rating', ascending = False).head(10)
best_rated_movie
# Out:
#                       Name  Year  Rating
# 7426       Love Qubool Hai  2020    10.0
# 4800            Half Songs  2021     9.7
# 2253                 Breed  2020     9.6
# 6100                  June  2021     9.4
# 12666  The Reluctant Crime  2020     9.4
# 4512          Gho Gho Rani  2019     9.4
# 10435             Ram-Path  2017     9.4
# 1505              Baikunth  2021     9.3
# 11759           Sindhustan  2019     9.3
# 1146          Ashok Vatika  2018     9.3

# %%
# Plot 10 Best rated movie
plt.figure(figsize=(13,6))
plots = sns.barplot(x = 'Name', y = 'Rating', data = best_rated_movie)
for bar in plots.patches:
  plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=15, xytext=(0, 8),
                   textcoords='offset points')
plt.title("Top 10 Best Rated movies", fontsize = 15)
plt.xlabel("Name of the Movie", fontsize = 13)
plt.ylabel("Rating", fontsize = 13)
plt.xticks(fontsize = 10,rotation = 45)
plt.show()

# %%
# Top 5 longest Moives
longest_movies = data_2[['Name','Duration (min)']].sort_values(by = 'Duration (min)',ascending = False).head()
longest_movies
# Out:
#                      Name  Duration (min)
# 4363   Gangs of Wasseypur             321
# 1177              Athidhi             300
# 12217               Tamas             298
# 10549              Reason             261
# 7344          LOC: Kargil             255

# %%
# Plot top 5 longest movies
plots = sns.barplot(x = 'Name', y = 'Duration (min)', data = longest_movies)
for bar in plots.patches:
  plots.annotate(format(bar.get_height()),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=13, xytext=(0, 8),
                   textcoords='offset points')
plt.title("Top 5 longest duration movies", fontsize = 15)
plt.xlabel("Name of the Movie", fontsize = 13)
plt.ylabel("Duration (min)", fontsize = 13)
plt.xticks(fontsize = 10,rotation = 45)
plt.ylim(0,400)
plt.grid(axis = 'y')
plt.show()

# %%
# Top 10 Genre for indian movies
Genre = pd.DataFrame(data_2[['Genre']].value_counts()).head(10)
Genre.reset_index(level = ['Genre'],inplace = True)
Genre.rename(columns = {0:'Count'},inplace = True)
Genre
# Out:
#                   Genre  Count
# 0                 Drama   2355
# 1                Action   1078
# 2              Thriller    693
# 3               Romance    608
# 4        Drama, Romance    461
# 5                Comedy    431
# 6  Action, Crime, Drama    400
# 7         Drama, Family    335
# 8         Action, Drama    273
# 9                Horror    273

# %%
# Plot for top 10 Genre for Indian Movies
plt.figure(figsize = (13,6))
plots = sns.barplot(x = 'Genre', y = 'Count', data = Genre)
for bar in plots.patches:
  plots.annotate(format(bar.get_height()),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=13, xytext=(0, 8),
                   textcoords='offset points')
plt.title("Top 10 Genre for Indian Movies", fontsize = 15)
plt.xlabel("Genre", fontsize = 13)
plt.ylabel("Count of Genre", fontsize = 13)
plt.xticks(rotation = 45)
plt.ylim(0,2700)
plt.show()

# %%
# Top 10 movies by Votes
top_votes = data_2[['Name','Votes']].sort_values(by = 'Votes', ascending = False)
top_votes
# Out:
#                          Name   Votes
# 7314               Life of Pi  591417
# 74                   3 Idiots  357889
# 7328                     Lion  220526
# 4311                   Gandhi  220118
# 12485  The Darjeeling Limited  185127
# ...                       ...     ...
# 10898           Sai Teri Maya       5
# 7426          Love Qubool Hai       5
# 8576          Mujhe Vachan Do       5
# 7408              Love in Goa       5
# 9996                   Pyaasi       5
#
# [11782 rows x 2 columns]
